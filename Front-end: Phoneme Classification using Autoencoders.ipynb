# %% [markdown]
# # Front-end: Phoneme Classification using Autoencoders

# %%
# NOTE: make this generalizable so we can generate subnetworks for each and every phoneme

# %% [markdown]
# ## Preprocessing

# %%
# 1. preprocess speech data to convert to melspectrogram (40 features per 20ms windows?)

# %%
# 2. apply Google library to detect frames with sound

# %%
# 3. save .npy with all the frames with the phoneme=1

# %% [markdown]
# ## Autoencoder (learning features)

# %%
# 4. load .npy with frames with phoneme=1

# %%
# 5. train an autoencoder for that specific phoneme

# %%
# 6. save the encoder

# %% [markdown]
# ## Classification network

# %%
# 7. generate dataset with phoneme=True and phoneme=False for classification training (mix different phonemes for phoneme=False)

# %%
# 8. train classifier, input data will be the output of passing the frame through the encoder

# %%
# 9. the output of the classifier is probability of input being that phoneme (pass that to back-end)
